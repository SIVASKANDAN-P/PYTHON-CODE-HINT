# %% [markdown]
# <a href="https://colab.research.google.com/github/SIVASKANDAN-P/PYTHON-CODE-HINT/blob/main/untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Connecting to gdrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/dataset/results fin bk - results.csv")

# %%
data.columns
# Out:
# Index(['ID', 'Model', 'tim-stmp', 'Epoch', 'Learning_rate', 'Lora_rank',
#        'Lora_alpha', 'quant_4bit', 'quant_8bit', 'Trainable_parameters',
#        'model_path', 'tokeniser_path', 'train_loss', 'eval_loss',
#        'eval_model_preparation_time', 'eval_rouge1', 'eval_rouge2',
#        'eval_rougeL', 'eval_rougeLsum', 'eval_meteor', 'eval_runtime',
#        'eval_samples_per_second', 'eval_steps_per_second'],
#       dtype='object')

# %%
data
# Out:
#               ID            Model         tim-stmp  Epoch  Learning_rate  \
# 0       C_R8_A32  CodeLlama-7b-hf  20241107_032806    1.0         0.0001
# 1      C_R16_A32  CodeLlama-7b-hf  20241107_150314    1.0         0.0001
# 2      C_R32_A32  CodeLlama-7b-hf  20241108_051618    1.0         0.0001
# 3      Cg_R8_A32  codegemma-7b-it  20241108_111902    1.0         0.0001
# 4     Cg_R16_A32  codegemma-7b-it  20241108_170304    1.0         0.0001
# ...          ...              ...              ...    ...            ...
# 996          NaN              NaN              NaN    NaN            NaN
# 997          NaN              NaN              NaN    NaN            NaN
# 998          NaN              NaN              NaN    NaN            NaN
# 999          NaN              NaN              NaN    NaN            NaN
# 1000         NaN              NaN              NaN    NaN            NaN
#
#       Lora_rank  Lora_alpha quant_4bit quant_8bit  \
# ...

# %%
data.dropna(inplace=True)

# %%
data.Model.value_counts()
# Out:
# Model
# CodeLlama-7b-hf    4
# codegemma-7b-it    4
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'Model', 'tim-stmp', 'Epoch', 'Learning_rate', 'Lora_rank',
#        'Lora_alpha', 'quant_4bit', 'quant_8bit', 'Trainable_parameters',
#        'model_path', 'tokeniser_path', 'train_loss', 'eval_loss',
#        'eval_model_preparation_time', 'eval_rouge1', 'eval_rouge2',
#        'eval_rougeL', 'eval_rougeLsum', 'eval_meteor', 'eval_runtime',
#        'eval_samples_per_second', 'eval_steps_per_second'],
#       dtype='object')

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 0 to 7
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           8 non-null      object
#  1   Model                        8 non-null      object
#  2   tim-stmp                     8 non-null      object
#  3   Epoch                        8 non-null      float64
#  4   Learning_rate                8 non-null      float64
#  5   Lora_rank                    8 non-null      float64
#  6   Lora_alpha                   8 non-null      float64
#  7   quant_4bit                   8 non-null      object
#  8   quant_8bit                   8 non-null      object
#  9   Trainable_parameters         8 non-null      object
#  10  model_path                   8 non-null      object
#  11  tokeniser_path               8 non-null      object
#  12  train_loss                   8 non-null      float64
# ...

# %%
data2[['ID','Model','eval_rouge1','eval_rouge2']]
# Out:
#            ID            Model  eval_rouge1  eval_rouge2
# 0    C_R8_A32  CodeLlama-7b-hf        0.778        0.621
# 1   C_R16_A32  CodeLlama-7b-hf        0.783        0.628
# 2   C_R32_A32  CodeLlama-7b-hf        0.793        0.646
# 3   Cg_R8_A32  codegemma-7b-it        0.816        0.678
# 4  Cg_R16_A32  codegemma-7b-it        0.822        0.692
# 5  Cg_R32_A32  codegemma-7b-it        0.816        0.681
# 6  Cg_R32_A64  codegemma-7b-it        0.823        0.691
# 7   C_R32_A64  CodeLlama-7b-hf        0.804        0.664

# %%
data2[['ID','Model','eval_meteor']]
# Out:
#            ID            Model  eval_meteor
# 0    C_R8_A32  CodeLlama-7b-hf        0.784
# 1   C_R16_A32  CodeLlama-7b-hf        0.790
# 2   C_R32_A32  CodeLlama-7b-hf        0.798
# 3   Cg_R8_A32  codegemma-7b-it        0.811
# 4  Cg_R16_A32  codegemma-7b-it        0.820
# 5  Cg_R32_A32  codegemma-7b-it        0.816
# 6  Cg_R32_A64  codegemma-7b-it        0.821
# 7   C_R32_A64  CodeLlama-7b-hf        0.810

# %%
data2[['ID','Model','eval_rougeL','eval_rougeLsum']]
# Out:
#            ID            Model  eval_rougeL  eval_rougeLsum
# 0    C_R8_A32  CodeLlama-7b-hf        0.758           0.767
# 1   C_R16_A32  CodeLlama-7b-hf        0.763           0.772
# 2   C_R32_A32  CodeLlama-7b-hf        0.774           0.782
# 3   Cg_R8_A32  codegemma-7b-it        0.798           0.805
# 4  Cg_R16_A32  codegemma-7b-it        0.806           0.812
# 5  Cg_R32_A32  codegemma-7b-it        0.800           0.806
# 6  Cg_R32_A64  codegemma-7b-it        0.807           0.813
# 7   C_R32_A64  CodeLlama-7b-hf        0.787           0.794

# %%
data2 = data.copy()
data2['train_loss'] = data2['train_loss'].round(2)
data2['eval_loss'] = data2['eval_loss'].round(2)
data2['eval_rouge1'] = data2['eval_rouge1'].round(3)
data2['eval_rouge2'] = data2['eval_rouge2'].round(3)
data2['eval_rougeL'] = data2['eval_rougeL'].round(3)
data2['eval_rougeLsum'] = data2['eval_rougeLsum'].round(3)
data2['eval_meteor'] = data2['eval_meteor'].round(3)

#data2.sort_values(by='ID', inplace=True,ascending=False)

# %%
data2[['ID','Model','train_loss','eval_loss']]
# Out:
#            ID            Model  train_loss  eval_loss
# 0    C_R8_A32  CodeLlama-7b-hf        0.74       0.78
# 1   C_R16_A32  CodeLlama-7b-hf        0.78       0.75
# 2   C_R32_A32  CodeLlama-7b-hf        0.77       0.72
# 3   Cg_R8_A32  codegemma-7b-it        0.70       0.70
# 4  Cg_R16_A32  codegemma-7b-it        0.73       0.67
# 5  Cg_R32_A32  codegemma-7b-it        0.71       0.68
# 6  Cg_R32_A64  codegemma-7b-it        0.77       0.65
# 7   C_R32_A64  CodeLlama-7b-hf        0.73       0.69

# %%
# Reshaping data to long format
data_long_clamma = pd.melt(data[data['Model']=='CodeLlama-7b-hf'][['ID','train_loss','eval_loss']], id_vars='ID', var_name='Loss_Type', value_name='Loss')
data_long_clamma
# Reshaping data to long format
data_long_cgemma = pd.melt(data[data['Model']=='codegemma-7b-it'][['ID','train_loss','eval_loss']], id_vars='ID', var_name='Loss_Type', value_name='Loss')
data_long_cgemma
# Out:
#            ID   Loss_Type      Loss
# 0   Cg_R8_A32  train_loss  0.695500
# 1  Cg_R16_A32  train_loss  0.726300
# 2  Cg_R32_A32  train_loss  0.710600
# 3  Cg_R32_A64  train_loss  0.771300
# 4   Cg_R8_A32   eval_loss  0.697629
# 5  Cg_R16_A32   eval_loss  0.668575
# 6  Cg_R32_A32   eval_loss  0.676765
# 7  Cg_R32_A64   eval_loss  0.649633

# %%
def plot(df, col, name, filter):
  # Reshaping data to long format
  data_reshaped = pd.melt(data[data['Model']==filter][['ID']+col], id_vars='ID', var_name=name+'_Type', value_name=name)
  sns.barplot(x='ID', y=name, hue=name+'_Type', data=data_reshaped)
  sns.set_theme(style="whitegrid")
  yticks = np.arange(0, data_reshaped[name].max() + 0.1, 0.1)
  plt.ylim(0, data_long_clamma[name].max() * 1.4)
  plt.yticks(yticks)
  plt.title("Train and test loss of CodeGemma")
  # Save the plot with 300 DPI
  plt.savefig("/content/drive/MyDrive/plots/Train_test_loss_"+filter, dpi=300, bbox_inches="tight")
  plt.show()

# %%
plot(data, ['train_loss','eval_loss'], 'Loss', 'CodeLlama-7b-hf')

# %%
plot(data, ['train_loss','eval_loss'], 'Loss', 'codegemma-7b-it')

# %%
sns.barplot(x='ID', y='Loss', hue='Loss_Type', data=data_long_clamma)
plt.title('Train and Test Loss')

# Increase y-axis limit
plt.ylim(0, data_long_clamma['Loss'].max() * 1.2)  # Extend slightly above the max value
yticks = np.arange(0, data_long_cgemma['Loss'].max() + 0.1, 0.1)  # Example: Ticks from 0 to max loss with step 0.1
plt.yticks(yticks)
# Save the plot with 300 DPI
plt.savefig("/content/drive/MyDrive/plots/.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
data.columns
# Out:
# Index(['ID', 'Model', 'tim-stmp', 'Epoch', 'Learning_rate', 'Lora_rank',
#        'Lora_alpha', 'quant_4bit', 'quant_8bit', 'Trainable_parameters',
#        'model_path', 'tokeniser_path', 'train_loss', 'eval_loss',
#        'eval_model_preparation_time', 'eval_rouge1', 'eval_rouge2',
#        'eval_rougeL', 'eval_rougeLsum', 'eval_meteor', 'eval_runtime',
#        'eval_samples_per_second', 'eval_steps_per_second'],
#       dtype='object')

# %%
lossdf = data[['ID','train_loss','eval_loss']]
lossdf['dif']= lossdf['train_loss']-lossdf['eval_loss']
lossdf
# Out:
# <ipython-input-39-9bb983f661cd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lossdf['dif']= lossdf['train_loss']-lossdf['eval_loss']
#            ID  train_loss  eval_loss       dif
# 0    C_R8_A32      0.7410   0.779454 -0.038454
# 1   C_R16_A32      0.7830   0.753878  0.029122
# 2   C_R32_A32      0.7746   0.721347  0.053253
# 3   Cg_R8_A32      0.6955   0.697629 -0.002129
# 4  Cg_R16_A32      0.7263   0.668575  0.057725
# 5  Cg_R32_A32      0.7106   0.676765  0.033835
# 6  Cg_R32_A64      0.7713   0.649633  0.121667
# 7   C_R32_A64      0.7269   0.685306  0.041594

# %%
data[['ID','Model','eval_rouge1']]
# Out:
#            ID            Model  eval_rouge1
# 0    C_R8_A32  CodeLlama-7b-hf     0.778492
# 1   C_R16_A32  CodeLlama-7b-hf     0.782974
# 2   C_R32_A32  CodeLlama-7b-hf     0.792526
# 3   Cg_R8_A32  codegemma-7b-it     0.815759
# 4  Cg_R16_A32  codegemma-7b-it     0.822436
# 5  Cg_R32_A32  codegemma-7b-it     0.816491
# 6  Cg_R32_A64  codegemma-7b-it     0.823085
# 7   C_R32_A64  CodeLlama-7b-hf     0.804364

# %%
sns.lineplot(x='ID', y='eval_rouge1', data=data[data['Model']=='CodeLlama-7b-hf'],marker='o')
#plt.xticks(rotation=45)
plt.title('Rouge1 scores of CodeLlama')
# Save the plot with 300 DPI
plt.savefig("/content/drive/MyDrive/plots/Rouge1_scores_CodeLlama.png", dpi=300, bbox_inches="tight")

# %%
sns.lineplot(x='ID', y='eval_rouge1', data=data[data['Model']=='codegemma-7b-it'],marker='o')
#plt.xticks(rotation=45)
plt.title('Rouge1 score of CodeGemma')
# Save the plot with 300 DPI
plt.savefig("/content/drive/MyDrive/plots/Rouge1_scores_CodeLlama.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
data['eval_rouge2'] = data['eval_rouge2'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 0 to 7
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           8 non-null      object
#  1   Model                        8 non-null      object
#  2   tim-stmp                     8 non-null      object
#  3   Epoch                        8 non-null      float64
#  4   Learning_rate                8 non-null      float64
#  5   Lora_rank                    8 non-null      float64
#  6   Lora_alpha                   8 non-null      float64
#  7   quant_4bit                   8 non-null      object
#  8   quant_8bit                   8 non-null      object
#  9   Trainable_parameters         8 non-null      object
#  10  model_path                   8 non-null      object
#  11  tokeniser_path               8 non-null      object
#  12  train_loss                   8 non-null      float64
# ...

# %%
sns.lineplot(x='ID', y='eval_rouge2', data=data[data['Model']=='CodeLlama-7b-hf'] ,marker='o')
#plt.xticks(rotation=45)
plt.title('Rouge2 scores of CodeLlama')
# Save the plot with 300 DPI
plt.savefig("/content/drive/MyDrive/plots/Rouge2_scores_CodeLlama.png", dpi=300, bbox_inches="tight")

# %%
sns.lineplot(x='ID', y='eval_rouge2', data=data[data['Model']=='codegemma-7b-it'],marker='o')
#plt.xticks(rotation=45)
plt.title('Rouge2 scores of CodeGemma')
# Save the plot with 300 DPI
plt.savefig("/content/drive/MyDrive/plots/Rouge2_scores_CodeGemma.png", dpi=300, bbox_inches="tight")

# %%
sns.lineplot(x='ID', y='eval_rougeL', data=data[data['Model']=='CodeLlama-7b-hf'],marker='o')
#plt.xticks(rotation=45)
plt.title('RougeL scores of CodeLlama')
# Save the plot with 300 DPI
plt.savefig("/content/drive/MyDrive/plots/RougeL_scores_CodeLlama.png", dpi=300, bbox_inches="tight")

# %%
sns.lineplot(x='ID', y='eval_rougeL', data=data[data['Model']=='codegemma-7b-it'],marker='o')
#plt.xticks(rotation=45)
plt.title('RougeL scores of CodeGemma')
# Save the plot with 300 DPI
plt.savefig("/content/drive/MyDrive/plots/RougeL_scores_CodeGemma.png", dpi=300, bbox_inches="tight")

# %%
sns.lineplot(x='ID', y='eval_rougeLsum', data=data[data['Model']=='codegemma-7b-it'],marker='o')
#     plt.xticks(rotation=45)
plt.title('RougeLsum for CodeGemma')
# Save the plot with 300 DPI
plt.savefig("/content/drive/MyDrive/plots/RougeLsum_scores_CodeGemma.png", dpi=300, bbox_inches="tight")

# %%
sns.lineplot(x='ID', y='eval_rougeLsum', data=data[data['Model']=='CodeLlama-7b-hf'],marker='o')
# plt.xticks(rotation=45)
plt.title('RougeLsum of CodeLlama')
# Save the plot with 300 DPI
plt.savefig("/content/drive/MyDrive/plots/RougeLsum_scores_CodeLlama.png", dpi=300, bbox_inches="tight")

# %%
sns.lineplot(x='ID', y='eval_meteor', data=data[data['Model']=='codegemma-7b-it'],marker='o')
#     plt.xticks(rotation=45)
plt.title('Meteor scores of CodeGemma')
# Save the plot with 300 DPI
plt.savefig("/content/drive/MyDrive/plots/Meteor_scores_CodeGemma.png", dpi=300, bbox_inches="tight")

# %%
sns.lineplot(x='ID', y='eval_meteor', data=data[data['Model']=='CodeLlama-7b-hf'],marker='o')
plt.xticks(rotation=45)
plt.title('Meteor scores of CodeLlama')
# Save the plot with 300 DPI
plt.savefig("/content/drive/MyDrive/plots/Meteor_scores_CodeLlama.png", dpi=300, bbox_inches="tight")

# %%
sns.barplot(x='ID', y='Loss', hue='Loss_Type', data=data_long_cgemma)
plt.title('Train and Test Loss')
# Increase y-axis limit
plt.ylim(0, data_long_cgemma['Loss'].max() * 1.2)  # Extend slightly above the max value
yticks = np.arange(0, data_long_cgemma['Loss'].max() + 0.1, 0.2)  # Example: Ticks from 0 to max loss with step 0.1
plt.yticks(yticks)
# Save the plot with 300 DPI
# plt.savefig("/content/drive/MyDrive/plots/.png", dpi=300, bbox_inches="tight")
# plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x7f14585b7fd0>,
# ...
#  [Text(0, 0.0, '0.0'),
#   Text(0, 0.2, '0.2'),
#   Text(0, 0.4, '0.4'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.8, '0.8')])

# %%
data_long_cgemma
# Out:
#            ID   Loss_Type      Loss
# 0   Cg_R8_A32  train_loss  0.695500
# 1  Cg_R16_A32  train_loss  0.726300
# 2  Cg_R32_A32  train_loss  0.710600
# 3  Cg_R32_A64  train_loss  0.771300
# 4   Cg_R8_A32   eval_loss  0.697629
# 5  Cg_R16_A32   eval_loss  0.668575
# 6  Cg_R32_A32   eval_loss  0.676765
# 7  Cg_R32_A64   eval_loss  0.649633

# %% [markdown]
# Problem 1  easy leetcode
# Given two strings needle and haystack, return the index of the first occurrence of needle in haystack, or -1 if needle is not part of haystack.
#
#
#
# Example 1:
#
# Input: haystack = "sadbutsad", needle = "sad"
# Output: 0
# Explanation: "sad" occurs at index 0 and 6.
# The first occurrence is at index 0, so we return 0.
# Example 2:
#
# Input: haystack = "leetcode", needle = "leeto"
# Output: -1
# Explanation: "leeto" did not occur in "leetcode", so we return -1.
#
#
# Constraints:
#
# 1 <= haystack.length, needle.length <= 104
# haystack and needle consist of only lowercase English characters.

# %% [markdown]
# **Step 1:**
#     - Initialize a variable `index` to -1 to represent the not found case.
#
#     **Step 2:**
#     - Iterate through the `haystack` string using a loop.
#
#     **Step 3:**
#     - For each character in `haystack`, check if it matches the first character of `needle`.
#
#     **Step 4:**
#     - If a match is found, perform a character-by-character comparison of the remaining characters in `needle` with the characters in `haystack` starting from the next position.
#
#     **Step 5:**
#     - If all characters in `needle` match, update `index` to the starting index of the match in `haystack`.
#
#     **Step 6:**
#     - If the loop completes without finding a match, return `index` as -1.

# %% [markdown]
# Given a string s, return the number of segments in the string.
#
# A segment is defined to be a contiguous sequence of non-space characters.
#
#
#
# Example 1:
#
# Input: s = "Hello, my name is John"
# Output: 5
# Explanation: The five segments are ["Hello,", "my", "name", "is", "John"]
# Example 2:
#
# Input: s = "Hello"
# Output: 1
#
#
# Constraints:
#
# 0 <= s.length <= 300
# s consists of lowercase and uppercase English letters, digits, or one of the following characters "!@#$%^&*()_+-=',.:".
# The only space character in s is ' '.

# %% [markdown]
#   Response:
#     Step 1: Initialize a variable `segments` to 0.
#     Step 2: Iterate through the string `s`.
#     Step 3: If the current character is not a space, increment the `segments` variable.
#     Step 4: If the current character is a space and the previous character is also a space, do not increment the `segments` variable.
#     Step 5: Return the `segments` variable.

# %% [markdown]
# Given two strings s and goal, return true if and only if s can become goal after some number of shifts on s.
#
# A shift on s consists of moving the leftmost character of s to the rightmost position.
#
# For example, if s = "abcde", then it will be "bcdea" after one shift.
#
#
# Example 1:
#
# Input: s = "abcde", goal = "cdeab"
# Output: true
# Example 2:
#
# Input: s = "abcde", goal = "abced"
# Output: false
#
#
# Constraints:
#
# 1 <= s.length, goal.length <= 100
# s and goal consist of lowercase English letters.

# %% [markdown]
#  Response:
#     Step 1:
#     - Create a dictionary to store the character shifts for each letter in s.
#     - Iterate through s and calculate the shift for each letter by subtracting the index of the letter in s from the index of the letter in goal.
#     - Handle cases where the shift is negative by adding 26 to it.
#
#     Step 2:
#     - Create a new string to store the shifted s.
#     - Iterate through s again and apply the shifts calculated in step 1 to each letter.
#     - If the shifted letter is not in the dictionary, it means the shift is not possible, so return False.
#
#     Step 3:
#     - Compare the shifted s with goal.
#     - If they are equal, return True.
#     - Otherwise, return False.

# %% [markdown]
# Medium

# %% [markdown]
# For a stream of integers, implement a data structure that checks if the last k integers parsed in the stream are equal to value.
#
# Implement the DataStream class:
#
# DataStream(int value, int k) Initializes the object with an empty integer stream and the two integers value and k.
# boolean consec(int num) Adds num to the stream of integers. Returns true if the last k integers are equal to value, and false otherwise. If there are less than k integers, the condition does not hold true, so returns false.
#
#
# Example 1:
#
# Input
# ["DataStream", "consec", "consec", "consec", "consec"]
# [[4, 3], [4], [4], [4], [3]]
# Output
# [null, false, false, true, false]
#
# Explanation
# DataStream dataStream = new DataStream(4, 3); //value = 4, k = 3
# dataStream.consec(4); // Only 1 integer is parsed, so returns False.
# dataStream.consec(4); // Only 2 integers are parsed.
#                       // Since 2 is less than k, returns False.
# dataStream.consec(4); // The 3 integers parsed are all equal to value, so returns True.
# dataStream.consec(3); // The last k integers parsed in the stream are [4,4,3].
#                       // Since 3 is not equal to value, it returns False.
#
#
# Constraints:
#
# 1 <= value, num <= 109
# 1 <= k <= 105
# At most 105 calls will be made to consec.

# %% [markdown]
# **Step 1: Initialize the DataStream object.**
#     - The constructor initializes the value and k parameters, as well as an empty integer stream.
#
#     **Step 2: Implement the consec method.**
#     - The consec method adds the new integer num to the stream.
#     - It then checks if the size of the stream is less than k. If it is, the condition does not hold true, so it returns false.
#     - If the size of the stream is equal to k, it compares the last k integers in the stream with the value. If all of them are equal, it returns true; otherwise, it returns false.

# %% [markdown]
# Given two non-negative integers num1 and num2 represented as strings, return the product of num1 and num2, also represented as a string.
#
# Note: You must not use any built-in BigInteger library or convert the inputs to integer directly.
#
#
#
# Example 1:
#
# Input: num1 = "2", num2 = "3"
# Output: "6"
# Example 2:
#
# Input: num1 = "123", num2 = "456"
# Output: "56088"
#
#
# Constraints:
#
# 1 <= num1.length, num2.length <= 200
# num1 and num2 consist of digits only.
# Both num1 and num2 do not contain any leading zero, except the number 0 itself.

# %% [markdown]
#     Step 1: Initialize a result variable to store the product.
#     Step 2: Iterate over the digits of num2 in reverse order.
#     Step 3: For each digit in num2, multiply it with num1 and shift the result by the corresponding number of zeros based on the position of the digit in num2.
#     Step 4: Add the result to the final product variable.
#     Step 5: Return the final product as a string.

# %% [markdown]
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM

# %% [markdown]
# A magical string s consists of only '1' and '2' and obeys the following rules:
#
# The string s is magical because concatenating the number of contiguous occurrences of characters '1' and '2' generates the string s itself.
# The first few elements of s is s = "1221121221221121122……". If we group the consecutive 1's and 2's in s, it will be "1 22 11 2 1 22 1 22 11 2 11 22 ......" and the occurrences of 1's or 2's in each group are "1 2 2 1 1 2 1 2 2 1 2 2 ......". You can see that the occurrence sequence is s itself.
#
# Given an integer n, return the number of 1's in the first n number in the magical string s.
#
#
#
# Example 1:
#
# Input: n = 6
# Output: 3
# Explanation: The first 6 elements of magical string s is "122112" and it contains three 1's, so return 3.
# Example 2:
#
# Input: n = 1
# Output: 1
#
#
# Constraints:
#
# 1 <= n <= 105

# %% [markdown]
#    **Step 1:**
#     The problem requires us to find the number of 1's in the first n numbers of the magical string s.
#
#     **Step 2:**
#     The magical string s is generated by concatenating the number of consecutive occurrences of characters '1' and '2'.
#
#     **Step 3:**
#     To find the number of 1's in the first n numbers, we need to count the number of 1's in the occurrences of '1' and '2' in the first n numbers.
#
#     **Step 4:**
#     The occurrences of '1' and '2' in the first n numbers can be determined by finding the number of 1's and 2's in the decimal representation of n.
#
#     **Step 5:**
#     For each digit in the decimal representation of n, we can count the number of 1's by subtracting the number of 2's in that digit.
#
#     **Step 6:**
#     The number of 1's in the first n numbers of s is the sum of the number of 1's in the decimal representation of n for each digit.

# %% [markdown]
# Hard

# %% [markdown]
# We can scramble a string s to get a string t using the following algorithm:
#
# If the length of the string is 1, stop.
# If the length of the string is > 1, do the following:
# Split the string into two non-empty substrings at a random index, i.e., if the string is s, divide it to x and y where s = x + y.
# Randomly decide to swap the two substrings or to keep them in the same order. i.e., after this step, s may become s = x + y or s = y + x.
# Apply step 1 recursively on each of the two substrings x and y.
# Given two strings s1 and s2 of the same length, return true if s2 is a scrambled string of s1, otherwise, return false.
#
#
#
# Example 1:
#
# Input: s1 = "great", s2 = "rgeat"
# Output: true
# Explanation: One possible scenario applied on s1 is:
# "great" --> "gr/eat" // divide at random index.
# "gr/eat" --> "gr/eat" // random decision is not to swap the two substrings and keep them in order.
# "gr/eat" --> "g/r / e/at" // apply the same algorithm recursively on both substrings. divide at random index each of them.
# "g/r / e/at" --> "r/g / e/at" // random decision was to swap the first substring and to keep the second substring in the same order.
# "r/g / e/at" --> "r/g / e/ a/t" // again apply the algorithm recursively, divide "at" to "a/t".
# "r/g / e/ a/t" --> "r/g / e/ a/t" // random decision is to keep both substrings in the same order.
# The algorithm stops now, and the result string is "rgeat" which is s2.
# As one possible scenario led s1 to be scrambled to s2, we return true.
# Example 2:
#
# Input: s1 = "abcde", s2 = "caebd"
# Output: false
# Example 3:
#
# Input: s1 = "a", s2 = "a"
# Output: true
#
#
# Constraints:
#
# s1.length == s2.length
# 1 <= s1.length <= 30

# %% [markdown]
#   **Step 1:**
#     The problem involves checking if one string is a scrambled version of another. The scrambling process involves randomly dividing the string into substrings, swapping them, and recursively applying the same process to each substring.
#
#     **Step 2:**
#     To solve this problem, we can use a recursive approach. The base case is when the string has only one character, which is always considered a valid scrambled version of itself.
#
#     **Step 3:**
#     For strings with more than one character, we randomly choose an index to divide the string into two substrings. We then recursively check if both substrings, when scrambled, can form the original string.
#
#     **Step 4:**
#     To check if a substring can form the original string, we can compare it to the original string after removing the other substring. If the remaining substring is the same as the original substring, then the original string can be formed by scrambling the substring.
#
#     **Step 5:**
#     We can use a recursive helper function to perform the scrambling process. The helper function takes the original string and the remaining substring as input. It randomly divides the remaining substring and recursively checks if the two substrings, when combined with the original substring, form the original string.
#
#     **Step 6:**
#     The main function takes two strings as input and calls the recursive helper function. If the helper function returns true, it means that the second string is a scrambled version of the first string, and the main function returns true. Otherwise, it returns false.

# %% [markdown]
# jjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj

# %% [markdown]
# You are given an array words of size n consisting of non-empty strings.
#
# We define the score of a string term as the number of strings words[i] such that term is a prefix of words[i].
#
# For example, if words = ["a", "ab", "abc", "cab"], then the score of "ab" is 2, since "ab" is a prefix of both "ab" and "abc".
# Return an array answer of size n where answer[i] is the sum of scores of every non-empty prefix of words[i].
#
# Note that a string is considered as a prefix of itself.
#
#
#
# Example 1:
#
# Input: words = ["abc","ab","bc","b"]
# Output: [5,4,3,2]
# Explanation: The answer for each string is the following:
# - "abc" has 3 prefixes: "a", "ab", and "abc".
# - There are 2 strings with the prefix "a", 2 strings with the prefix "ab", and 1 string with the prefix "abc".
# The total is answer[0] = 2 + 2 + 1 = 5.
# - "ab" has 2 prefixes: "a" and "ab".
# - There are 2 strings with the prefix "a", and 2 strings with the prefix "ab".
# The total is answer[1] = 2 + 2 = 4.
# - "bc" has 2 prefixes: "b" and "bc".
# - There are 2 strings with the prefix "b", and 1 string with the prefix "bc".
# The total is answer[2] = 2 + 1 = 3.
# - "b" has 1 prefix: "b".
# - There are 2 strings with the prefix "b".
# The total is answer[3] = 2.
# Example 2:
#
# Input: words = ["abcd"]
# Output: [4]
# Explanation:
# "abcd" has 4 prefixes: "a", "ab", "abc", and "abcd".
# Each prefix has a score of one, so the total is answer[0] = 1 + 1 + 1 + 1 = 4.
#
#
# Constraints:
#
# 1 <= words.length <= 1000
# 1 <= words[i].length <= 1000
# words[i] consists of lowercase English letters.

# %% [markdown]
# **Step 1:**
#     - Initialize a variable to store the largest number found so far.
#     - Set this variable to the smallest possible integer value.
#
#     **Step 2:**
#     - Use a loop to iterate through each element in the list.
#
#     **Step 3:**
#     - For each element, compare it to the current largest number.
#     - If the element is greater, update the largest number variable.
#
#     **Step 4:**
#     - After iterating through the entire list, return the final value of the largest number variable.

# %% [markdown]
# njjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj

# %% [markdown]
# Given a string s. In one step you can insert any character at any index of the string.
#
# Return the minimum number of steps to make s palindrome.
#
# A Palindrome String is one that reads the same backward as well as forward.
#
#
#
# Example 1:
#
# Input: s = "zzazz"
# Output: 0
# Explanation: The string "zzazz" is already palindrome we do not need any insertions.
# Example 2:
#
# Input: s = "mbadm"
# Output: 2
# Explanation: String can be "mbdadbm" or "mdbabdm".
# Example 3:
#
# Input: s = "leetcode"
# Output: 5
# Explanation: Inserting 5 characters the string becomes "leetcodocteel".
#
#
# Constraints:
#
# 1 <= s.length <= 500
# s consists of lowercase English letters.

# %% [markdown]
#   **Step 1:**
#     - To solve this problem, we need to find the minimum number of insertions required to make the string palindrome.
#     - We can use dynamic programming to solve this problem.
#
#     **Step 2:**
#     - Create a 2D table dp where dp[i][j] represents the minimum number of insertions required to make the substring s[i...j] palindrome.
#     - Initialize dp[i][i] to 0, as a single character is already palindrome.
#     - For i < j, we can check if s[i] == s[j]. If they are equal, then dp[i][j] = dp[i+1][j-1].
#     - Otherwise, we need to consider two cases:
#         - Inserting s[j] at the beginning of the substring s[i...j]: dp[i][j] = dp[i+1][j] + 1
#         - Inserting s[i] at the end of the substring s[i...j]: dp[i][j] = dp[i][j-1] + 1
#
#     **Step 3:**
#     - The final answer is dp[0][n-1], where n is the length of the string.
#
#     **Step 4:**
#     - To find the minimum number of insertions

# %% [markdown]
# skip above

# %% [markdown]
# Given two strings s and t, transform string s into string t using the following operation any number of times:
#
# Choose a non-empty substring in s and sort it in place so the characters are in ascending order.
# For example, applying the operation on the underlined substring in "14234" results in "12344".
# Return true if it is possible to transform s into t. Otherwise, return false.
#
# A substring is a contiguous sequence of characters within a string.
#
#
#
# Example 1:
#
# Input: s = "84532", t = "34852"
# Output: true
# Explanation: You can transform s into t using the following sort operations:
# "84532" (from index 2 to 3) -> "84352"
# "84352" (from index 0 to 2) -> "34852"
# Example 2:
#
# Input: s = "34521", t = "23415"
# Output: true
# Explanation: You can transform s into t using the following sort operations:
# "34521" -> "23451"
# "23451" -> "23415"
# Example 3:
#
# Input: s = "12345", t = "12435"
# Output: false
#
#
# Constraints:
#
# s.length == t.length
# 1 <= s.length <= 105
# s and t consist of only digits.

# %% [markdown]
# **Step 1:**
#     - The problem requires transforming string s into string t using a series of sort operations.
#     - The key step is to identify the non-empty substrings in s that need to be sorted to achieve the transformation.
#
#     **Step 2:**
#     - To find the substrings, we can iterate through s and compare each pair of adjacent characters.
#     - If the characters are in descending order, we have found a substring that needs to be sorted.
#
#     **Step 3:**
#     - For each identified substring, we can sort it in ascending order using a built-in sorting algorithm.
#     - The sorted substring will then be in the correct position in the transformed string.
#
#     **Step 4:**
#     - After sorting all the substrings, we can compare the transformed string with t.
#     - If they are equal, it means we have successfully transformed s into t.
#
#     **Step 5:**
#     - If we cannot find a way to transform s into t using the sort operations, we return false.

# %%
ans = pd.DataFrame(columns=['Ques', 'Res','Diff'])

# %%
diff = input("Difficulty")
ques = input("Question")
re = input("Response")
ans = pd.concat([ans, pd.DataFrame([{'Ques': ques, 'Res': re, 'Diff': diff}])], ignore_index=True) # Use pd.concat instead of append
# Out:
# DifficultyEasy
# QuestionGiven two strings needle and haystack, return the index of the first occurrence of needle in haystack, or -1 if needle is not part of haystack.  Example 1:  Input: haystack = "sadbutsad", needle = "sad" Output: 0 Explanation: "sad" occurs at index 0 and 6. The first occurrence is at index 0, so we return 0. Example 2:  Input: haystack = "leetcode", needle = "leeto" Output: -1 Explanation: "leeto" did not occur in "leetcode", so we return -1.  Constraints:  1 <= haystack.length, needle.length <= 104 haystack and needle consist of only lowercase English characters.
# ...

# %%
ans
# Out:
#                                                 Ques  \
# 0  Given two strings s and t, transform string s ...
# 1  You are given an array words of size n consist...
# 2  We can scramble a string s to get a string t u...
# 3  A magical string s consists of only '1' and '2...
# 4  Given two non-negative integers num1 and num2 ...
# 5  For a stream of integers, implement a data str...
# 6  Given two strings s and goal, return true if a...
# 7  Given a string s, return the number of segment...
# 8  Given two strings needle and haystack, return ...
#
#                                                  Res    Diff
# 0  Step 1: - The problem requires transforming st...    Hard
# 1  Step 1: - Initialize a variable to store the l...    Hard
# 2  Step 1: The problem involves checking if one s...    Hard
# 3  Step 1: The problem requires us to find the nu...  Medium
# 4  Step 1: Initialize a result variable to store ...  Medium
# 5  Step 1: Initialize the DataStream object. - Th...  Medium
# ...

# %%
print(ques)
# Out:
# Given two strings s and t, transform string s into string t using the following operation any number of times:  Choose a non-empty substring in s and sort it in place so the characters are in ascending order. For example, applying the operation on the underlined substring in "14234" results in "12344". Return true if it is possible to transform s into t. Otherwise, return false.  A substring is a contiguous sequence of characters within a string.  Example 1:  Input: s = "84532", t = "34852" Output: true Explanation: You can transform s into t using the following sort operations: "84532" (from index 2 to 3) -> "84352" "84352" (from index 0 to 2) -> "34852" Example 2:  Input: s = "34521", t = "23415" Output: true Explanation: You can transform s into t using the following sort operations: "34521" -> "23451" "23451" -> "23415" Example 3:  Input: s = "12345", t = "12435" Output: false  Constraints:  s.length == t.length 1 <= s.length <= 105 s and t consist of only digits.

# %%
ans.to_csv(r'/content/drive/MyDrive/plots/ansfin.csv', index=False)

# %%
def prompt(ques,res):
  return '''
  Your are a coding tutor tasked with evaluating responses generated by LLM model trained for generating
  steps for solving the problem in natural language. Also consider the response is only aimed at guiding the learner not to provide direct solution.
  Evaluate the correctness of response according to question.
  Below is the question:
  {ques}
  Below is the response generated by Model:
  {res}

  Provide a response if it is relevant and correct as Relevant else Not Relevant.
  Also provide a 1 line feedback to be provided to LLM to improve its response
  '''.format(ques=ques,res=res)

# %%
restem = '''
  Response:
    Step 1: **Split the String:** The first step is to split the string into segments. We can do this by iterating over the string and checking for spaces. If we encounter a space, we know that we have reached the end of a segment.
    Step 2: **Count Segments:** Once we have split the string into segments, we can simply count the number of segments to get the number of segments in the string.
    Step 3: **Handle Empty Segments:** The problem states that the string may contain empty segments. We need to handle these empty segments by not counting them in the final count.
    Step 4: **Return Count:** Finally, we return the count of segments minus the number of empty segments.
    '''
i=7
print(prompt(ans.iloc[i]['Ques'],restem))
# Out:
#   Your are a coding tutor tasked with evaluating responses generated by LLM model trained for generating
#   steps for solving the problem in natural language. Also consider the response is only aimed at guiding the learner not to provide direct solution.
#   Evaluate the correctness of response according to question.
#   Below is the question:
#   Given a string s, return the number of segments in the string.  A segment is defined to be a contiguous sequence of non-space characters.  Example 1:  Input: s = "Hello, my name is John" Output: 5 Explanation: The five segments are ["Hello,", "my", "name", "is", "John"] Example 2:  Input: s = "Hello" Output: 1  Constraints:  0 <= s.length <= 300 s consists of lowercase and uppercase English letters, digits, or one of the following characters "!@#$%^&*()_+-=',.:". The only space character in s is ' '.
#   Below is the response generated by Model:
#
#   Response:
# ...

# %%
ans.loc[i,'Feed'] = '''NA'''

# %%
ans.loc[i,'Updres'] = "NA"
ans.loc[i,'GPT res'] = "Relevant"
ans.loc[i,'Res'] = restem

# %%
ans
# Out:
#                                                 Ques  \
# 0  Given two strings s and t, transform string s ...
# 1  You are given an array words of size n consist...
# 2  We can scramble a string s to get a string t u...
# 3  A magical string s consists of only '1' and '2...
# 4  Given two non-negative integers num1 and num2 ...
# 5  For a stream of integers, implement a data str...
# 6  Given two strings s and goal, return true if a...
# 7  Given a string s, return the number of segment...
# 8  Given two strings needle and haystack, return ...
#
#                                                  Res    Diff  \
# 0  Step 1: - The problem requires transforming st...    Hard
# 1  Step 1: - Initialize a variable to store the l...    Hard
# 2  Step 1: The problem involves checking if one s...    Hard
# 3   \n    Step 1: **Understand the Magical String...  Medium
# 4  Step 1: Initialize a result variable to store ...  Medium
# 5   \n      Response:\n    Step 1: Initialize an ...  Medium
# ...

# %%
ans
# Out:
#                                                 Ques  \
# 0  Given two strings s and t, transform string s ...
# 1  You are given an array words of size n consist...
# 2  We can scramble a string s to get a string t u...
# 3  A magical string s consists of only '1' and '2...
# 4  Given two non-negative integers num1 and num2 ...
# 5  For a stream of integers, implement a data str...
# 6  Given two strings s and goal, return true if a...
# 7  Given a string s, return the number of segment...
# 8  Given two strings needle and haystack, return ...
#
#                                                  Res    Diff
# 0  Step 1: - The problem requires transforming st...    Hard
# 1  Step 1: - Initialize a variable to store the l...    Hard
# 2  Step 1: The problem involves checking if one s...    Hard
# 3  Step 1: The problem requires us to find the nu...  Medium
# 4  Step 1: Initialize a result variable to store ...  Medium
# 5  Step 1: Initialize the DataStream object. - Th...  Medium
# ...

# %%
ans = pd.read_csv("/content/drive/MyDrive/plots/ans.csv")

# %%
i=8
print(prompt(ans.iloc[i]['Ques'],ans.iloc[i]['Res']))
# Out:
#   Your are a coding tutor tasked with evaluating responses generated by LLM model trained for generating
#   steps for solving the problem in natural language. Also consider the response is only aimed at guiding the learner not to provide direct solution.
#   Evaluate the correctness of response according to question.
#   Below is the question:
#   Given two strings needle and haystack, return the index of the first occurrence of needle in haystack, or -1 if needle is not part of haystack.  Example 1:  Input: haystack = "sadbutsad", needle = "sad" Output: 0 Explanation: "sad" occurs at index 0 and 6. The first occurrence is at index 0, so we return 0. Example 2:  Input: haystack = "leetcode", needle = "leeto" Output: -1 Explanation: "leeto" did not occur in "leetcode", so we return -1.  Constraints:  1 <= haystack.length, needle.length <= 104 haystack and needle consist of only lowercase English characters.
#   Below is the response generated by Model:
# ...

# %%
import openai

# Your OpenAI API key (make sure it's kept secure)
openai.api_key = 'your-openai-api-key'

# Function to get response from ChatGPT
def get_chatgpt_response(prompt):
    response = openai.Completion.create(
        engine="gpt-3.5-turbo",  # or use gpt-4 if you have access
        prompt=prompt,
        max_tokens=150,  # You can adjust the max_tokens to control the length of the response
        n=1,  # Number of responses to generate
        stop=None,  # You can specify stop tokens if needed
        temperature=0.7  # Controls randomness in response (0.0 to 1.0)
    )

    # Extract and return the generated text
    return response.choices[0].text.strip()

# Example usage:
prompt = "What is the capital of France?"
response = get_chatgpt_response(prompt)
print(response)

# %%
dataset = pd.read_csv("/content/drive/MyDrive/dataset/data300.csv")

# %%
dataset[['instruction','response']].iloc[30:].head(10)
# Out:
#                                           instruction  \
# 30  Write Python code to solve the task.\nWrite a ...
# 31  Write Python code to solve the task.\nWrite a ...
# 32  Write Python code to solve the task.\nWrite a ...
# 33  Write Python code to solve the task.\nWrite a ...
# 34  Write Python code to solve the task.\nFor a gi...
# 35  Write Python code to solve the task.\nFor a gi...
# 36  Write Python code to solve the task.\nFor a gi...
# 37  Write Python code to solve the task.\n\...
# 38  Write Python code to solve the task.\n\...
# 39  Write Python code to solve the task.\n\...
#
#                                              response
# 30  Step 1:  We need to find a way to search for a...
# 31  Step 1:  We need to find a pattern in a ring-s...
# 32  Step 1:  To solve this problem, we need to fin...
# 33  Step 1:  The question requires finding a patte...
# 34  Step 1:  The problem requires us to find the m...
# 35  Step 1:  To solve this problem, we need to fin...
# ...

# %%
prob='''
Write Python code to solve the task. You have a given integer n. Find the number of ways to fill all 3 × n tiles with the shape described in the picture below. Upon filling, no empty spaces are allowed. Shapes cannot overlap. The left one is the shape and the right one is 3 × n tiles. Input The only line contains one integer n (1 ≤ n ≤ 60) — the length. Output Print the number of ways to fill. Examples Input 4 Output 4 Input 1 Output 0 Note In the first example, there are 4 possible cases of filling. In the second example, you cannot fill the shapes in 3 × 1 tiles
'''
resp ='''
Response:
    Step 1: **Understand the problem:** The problem requires us to find the number of ways to fill a 3 x n tile with a given shape without any empty spaces or overlapping.

    Step 2: **Break down the problem:** The problem can be broken down into smaller subproblems. We can consider the tile as a series of columns, and we need to find the number of ways to fill each column with the shape.

    Step 3: **Base cases:** For a tile with only one column, there is only one way to fill it. For a tile with two columns, there are two ways to fill it.

    Step 4: **Recursive formula:** For a tile with n columns, we can fill the first column in any of the two ways, and then we can recursively solve the subproblem of filling the remaining n-1 columns.

    Step 5: **Modulus operation:** Since the answer can be large, we need to take the modulus of the answer with 10^9 + 7.

    Step 6: **Handle edge cases:** The problem states that the input will be between 1 and 60, so we need to handle the edge cases for n = 1 and n = 2.
'''
Relevance = 'NA'

# %%
prob='''
Write Python code to solve the task. The penultimate task involved the calculation of the typical Fibonacci sequence up to the nth term. Input – single integer n Output – Fibonacci sequence up to the nth term, all terms on a new line SAMPLE INPUT 5 SAMPLE OUTPUT 1 1 2 3 5
'''
resp='''
  Response:
    Step 1: The program should first take an integer input from the user, which represents the number of terms in the Fibonacci sequence to be generated.
    Step 2: The program should then initialize two variables, `a` and `b`, to store the first two terms of the Fibonacci sequence, which are 1 and 1, respectively.
    Step 3: The program should then use a loop to generate the remaining terms in the sequence. The loop should iterate `n-2` times, as the first two terms have already been initialized.
    Step 4: Inside the loop, the program should calculate the next term in the sequence by adding the previous two terms. This can be done by assigning the sum of `a` and `b` to a new variable, `c`.
    Step 5: The program should then print the next term in the sequence.
    Step 6: The program should then update the values of `a` and `b` to the next two terms in the sequence. This can be done by assigning the value of `b` to `a` and the value of `c` to `b`.
    Step 7: The program should then continue to iterate through the loop until the desired number of terms in the sequence have been generated.
'''

# %% [markdown]
# Relevance: Relevant
#
# The response outlines a step-by-step process for generating a Fibonacci sequence in Python. It correctly describes the initialization, looping mechanism, and updating of variables necessary to compute the sequence. While some minor details could be made clearer, such as handling edge cases (e.g., when n is 1 or 2), the response effectively guides the learner without providing direct code.
#
# Feedback:
# "Consider clarifying how to handle edge cases for small values of n (e.g., 1 or 2) and ensuring each generated term is printed on a new line as required by the output format."

# %%
prob='''
Write Python code to solve the task. Our juniors has just entered in coding community. Their first task is to find the frequency of Best numbers present in given list of elements. Best numbers are numbers which are divisible by 2. SAMPLE INPUT 2 5 1 2 3 4 5 3 1 3 5 SAMPLE OUTPUT 2 0 Explanation Number of test cases=2 1st test case, number of elements =5 Best numbers are 2 , 4 ; frequency=2 2nd test case, number of elements =3 No Best numbers
'''
resp='''
   Response:
    Step 1: The program should first take the number of test cases as input.
    Step 2: For each test case, it should take the number of elements in the list as input.
    Step 3: It should then take the elements of the list as input.
    Step 4: It should then check if each element is divisible by 2.
    Step 5: If an element is divisible by 2, it should increment the frequency of best numbers.
    Step 6: After checking all elements, it should print the frequency of best numbers for each test case.
'''

# %% [markdown]
# Relevance: Relevant
#
# The response correctly outlines the logical steps to solve the problem. It captures key points such as taking the number of test cases as input, iterating through each test case, checking for divisibility by 2, and counting the "best numbers." However, the explanation could benefit from explicitly emphasizing how to handle multiple test cases and clearly delineating the inputs and outputs for each test case.
#
# Feedback:
# "Clarify the process of handling multiple test cases and explicitly mention printing the frequency for each test case separately to align with the required output format."

# %%
prob='''
Write Python code to solve the task. On a rod of length a+b+c, lengths a, b, c are measured at random. Your task is to calculate the probability that no point of the measured lines will coincide. INPUT: First line contains the number of test cases T, followed by T lines, each line contains three space separated integers a, b, c. OUTPUT: For each test case, display the desired result in the form of m / n in a single line. Constraints: 1 ≤ T ≤ 10 1 ≤ a, b, c ≤ 100000 NOTE: If "m" and "n" are divisible to each other, then do not divide them. e.g. If your answer is 2/4, do not solve further. Print only "2/4" not "1/2". SAMPLE INPUT 1 1 1 1 SAMPLE OUTPUT 1 / 4 Explanation If all the segments have equal length, then the probability will be 1/4.
'''
resp='''

'''

# %%
prob='''
	Write Python code to solve the task. Write a program which finds a pattern $p$ in a ring shaped text $s$.  Constraints * $1 \leq $ length of $p \leq $ length of $s \leq 100$ * $s$ and $p$ consists of lower-case letters Input In the first line, the text $s$ is given. In the second line, the pattern $p$ is given. Output If $p$ is in $s$, print Yes in a line, otherwise No. Examples Input vanceknowledgetoad advance Output Yes Input vanceknowledgetoad advanced Output No
'''
resp='''
   Step 1: **Understand the problem:** The goal is to find a pattern in a ring-shaped text. The text is given in the first line and the pattern is given in the second line.
    Step 2: **Create a dictionary:** Create a dictionary to store the characters in the text and their corresponding positions.
    Step 3: **Check for the pattern:** Iterate over the pattern and check if each character is in the dictionary. If a character is not in the dictionary, the pattern cannot be found in the text.
    Step 4: **Check for the position:** If a character is in the dictionary, check if the position of the character in the text is within the range of the pattern. If the position is not within the range, the pattern cannot be found in the text.
    Step 5: **Return the result:** If the pattern is found in the text, return Yes. Otherwise, return No.
'''

# %%
ans_dataset = pd.DataFrame(columns=['Ques', 'Res','Relevance'])

# %%
print(prompt(prob,resp))
# Out:
#   Your are a coding tutor tasked with evaluating responses generated by LLM model trained for generating
#   steps for solving the problem in natural language. Also consider the response is only aimed at guiding the learner not to provide direct solution.
#   Evaluate the correctness of response according to question.
#   Below is the question:
#
# Write Python code to solve the task. Our juniors has just entered in coding community. Their first task is to find the frequency of Best numbers present in given list of elements. Best numbers are numbers which are divisible by 2. SAMPLE INPUT 2 5 1 2 3 4 5 3 1 3 5 SAMPLE OUTPUT 2 0 Explanation Number of test cases=2 1st test case, number of elements =5 Best numbers are 2 , 4 ; frequency=2 2nd test case, number of elements =3 No Best numbers
#
#   Below is the response generated by Model:
#
#    Response:
#     Step 1: The program should first take the number of test cases as input.
# ...

# %%
ans.loc[i,'Ques'] = prob
ans.loc[i,'Res'] = resp
ans.loc[i,'Relevance'] = restem
